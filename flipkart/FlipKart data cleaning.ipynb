# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('phone_dataset.csv')

# %%
df.head()
# Out:
#                                             Name    Price  Overall Rating
# 0  OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)  ₹17,670             4.4  \
# 1       OnePlus 8T 5G (Aquamarine Green, 128 GB)  ₹29,990             4.4
# 2           OnePlus 8T 5G (Lunar Silver, 128 GB)  ₹29,990             4.4
# 3            Redmi 9A Sport (Coral Green, 32 GB)   ₹8,448             4.2
# 4                  POCO C51 (Power Black, 64 GB)   ₹6,499             4.2
#
#   Total no of rating Total no of reviews 5 star rating 4 star rating
# 0           (88,862)       6,219 Reviews        57,463        18,556  \
# 1              (168)          16 Reviews           118            24
# 2              (168)          16 Reviews           118            24
# 3            (7,006)         498 Reviews         3,929         1,742
# 4           (37,049)       1,815 Reviews        22,421         6,841
#
#   3 star rating 2 star rating 1 star rating  Camera Rating  Battery Rating
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 789 entries, 0 to 788
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 789 non-null    object
#  1   Price                789 non-null    object
#  2   Overall Rating       789 non-null    float64
#  3   Total no of rating   789 non-null    object
#  4   Total no of reviews  789 non-null    object
#  5   5 star rating        789 non-null    object
#  6   4 star rating        789 non-null    object
#  7   3 star rating        789 non-null    object
#  8   2 star rating        789 non-null    object
#  9   1 star rating        789 non-null    object
#  10  Camera Rating        789 non-null    float64
#  11  Battery Rating       789 non-null    float64
#  12  Display Rating       789 non-null    float64
#  13  Design Rating        789 non-null    float64
#  14  Variant              789 non-null    object
# ...

# %%
df['Price'].str.replace(',', '').str.replace('₹', '')
# Out:
# 0      17670
# 1      29990
# 2      29990
# 3       8448
# 4       6499
#        ...
# 784    44510
# 785    39815
# 786    29948
# 787    39485
# 788    17680
# Name: Price, Length: 789, dtype: object

# %%
df['Price'] = df['Price'].str.replace(',', '').str.replace('₹', '')
df['5 star rating'] = df['5 star rating'].str.replace(',', '')
df['4 star rating'] = df['4 star rating'].str.replace(',', '')
df['3 star rating'] = df['3 star rating'].str.replace(',', '')
df['2 star rating'] = df['2 star rating'].str.replace(',', '')
df['1 star rating'] = df['1 star rating'].str.replace(',', '')
df['Total no of reviews'] = df['Total no of reviews'].str.replace(',', '').str.replace('Reviews', '')
df['Total no of rating'] = df['Total no of rating'].str.replace(',', '').str.replace('(', '').str.replace(')', '')

# %%
df.head(2)
# Out:
#                                             Name  Price  Overall Rating
# 0  OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)  17670             4.4  \
# 1       OnePlus 8T 5G (Aquamarine Green, 128 GB)  29990             4.4
#
#   Total no of rating Total no of reviews 5 star rating 4 star rating
# 0              88862               6219          57463         18556  \
# 1                168                 16            118            24
#
#   3 star rating 2 star rating 1 star rating  Camera Rating  Battery Rating
# 0          5546          2143          5154            4.1             4.2  \
# 1             9             2            15            4.1             4.2
#
#    Display Rating  Design Rating                Variant
# 0             4.2            4.2  6 GB RAM | 128 GB ROM  \
# 1             4.4            4.2  8 GB RAM | 128 GB ROM
#
#                         Display                                Camera
# ...

# %%
df['Price'] = df['Price'].astype(int)
df['5 star rating'] = df['5 star rating'].astype(int)
df['4 star rating'] = df['4 star rating'].astype(int)
df['3 star rating'] = df['3 star rating'].astype(int)
df['2 star rating'] = df['2 star rating'].astype(int)
df['1 star rating'] = df['1 star rating'].astype(int)
df['Total no of reviews'] = df['Total no of reviews'].astype(int)
df['Total no of rating'] = df['Total no of rating'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 789 entries, 0 to 788
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 789 non-null    object
#  1   Price                789 non-null    int32
#  2   Overall Rating       789 non-null    float64
#  3   Total no of rating   789 non-null    int32
#  4   Total no of reviews  789 non-null    int32
#  5   5 star rating        789 non-null    int32
#  6   4 star rating        789 non-null    int32
#  7   3 star rating        789 non-null    int32
#  8   2 star rating        789 non-null    int32
#  9   1 star rating        789 non-null    int32
#  10  Camera Rating        789 non-null    float64
#  11  Battery Rating       789 non-null    float64
#  12  Display Rating       789 non-null    float64
#  13  Design Rating        789 non-null    float64
#  14  Variant              789 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Price', 'Overall Rating', 'Total no of rating',
#        'Total no of reviews', '5 star rating', '4 star rating',
#        '3 star rating', '2 star rating', '1 star rating', 'Camera Rating',
#        'Battery Rating', 'Display Rating', 'Design Rating', 'Variant',
#        'Display', 'Camera', 'Offers'],
#       dtype='object')

# %%
df.drop_duplicates(subset=['Name'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 446 entries, 0 to 747
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 446 non-null    object
#  1   Price                446 non-null    int32
#  2   Overall Rating       446 non-null    float64
#  3   Total no of rating   446 non-null    int32
#  4   Total no of reviews  446 non-null    int32
#  5   5 star rating        446 non-null    int32
#  6   4 star rating        446 non-null    int32
#  7   3 star rating        446 non-null    int32
#  8   2 star rating        446 non-null    int32
#  9   1 star rating        446 non-null    int32
#  10  Camera Rating        446 non-null    float64
#  11  Battery Rating       446 non-null    float64
#  12  Display Rating       446 non-null    float64
#  13  Design Rating        446 non-null    float64
#  14  Variant              446 non-null    object
# ...

# %%
df.reset_index(inplace=True)

# %%
df.tail()
# Out:
#      index                                 Name  Price  Overall Rating
# 441    740        vivo Y02 (Cosmic Grey, 32 GB)   8499             4.2  \
# 442    741     vivo T2 5G (Nitro Blaze, 128 GB)  18999             4.4
# 443    742   vivo T2 5G (Velocity Wave, 128 GB)  18999             4.4
# 444    745  vivo T2x 5G (Glimmer Black, 128 GB)  12999             4.4
# 445    747    vivo T2x 5G (Marine Blue, 128 GB)  12999             4.4
#
#      Total no of rating  Total no of reviews  5 star rating  4 star rating
# 441                 713                   34            454            120  \
# 442               40644                 2507          27323           8173
# 443               40644                 2507          27323           8173
# 444               49161                 2566          34034           8657
# 445               49161                 2566          34034           8657
#
#      3 star rating  2 star rating  1 star rating  Camera Rating
# ...

# %%
#highest rated phone
df.loc[df['Overall Rating'].idxmax()]
# Out:
# index                                                                225
# Name                                 APPLE iPhone 14 Plus (Blue, 128 GB)
# Price                                                              72999
# Overall Rating                                                       4.7
# Total no of rating                                                 13156
# Total no of reviews                                                  815
# 5 star rating                                                      10686
# 4 star rating                                                       1505
# 3 star rating                                                        308
# 2 star rating                                                        160
# 1 star rating                                                        497
# Camera Rating                                                        4.6
# Battery Rating                                                       4.6
# ...

# %%
#highest reviewed phone
df.loc[df['Total no of reviews'].idxmax()]
# Out:
# index                                                                528
# Name                                           Redmi 8 (Ruby Red, 64 GB)
# Price                                                              10990
# Overall Rating                                                       4.4
# Total no of rating                                                945272
# Total no of reviews                                                66920
# 5 star rating                                                     637794
# 4 star rating                                                     181100
# 3 star rating                                                      61582
# 2 star rating                                                      21648
# 1 star rating                                                      43148
# Camera Rating                                                        3.7
# Battery Rating                                                       4.3
# ...

# %%
#Best Camera Phone
df.loc[df['Camera Rating'].idxmax()]
# Out:
# index                                                                239
# Name                              APPLE iPhone 14 Pro Max (Gold, 128 GB)
# Price                                                             127999
# Overall Rating                                                       4.7
# Total no of rating                                                  1779
# Total no of reviews                                                  132
# 5 star rating                                                       1480
# 4 star rating                                                        165
# 3 star rating                                                         29
# 2 star rating                                                         24
# 1 star rating                                                         81
# Camera Rating                                                        4.7
# Battery Rating                                                       4.6
# ...

# %%
Top10_most_reviewed_phones = df.nlargest(10,'Total no of reviews')[['Name', 'Price','Total no of reviews','Overall Rating']]

# %%
Top10_most_reviewed_phones
# Out:
#                                              Name  Price  Total no of reviews
# 333                     Redmi 8 (Ruby Red, 64 GB)  10990                66920  \
# 357                   POCO F1 (Steel Blue, 64 GB)  12299                30044
# 325       Redmi Note 7 Pro (Neptune Blue, 128 GB)  17999                26316
# 25                Honor 9N (Sapphire Blue, 32 GB)   9473                21832
# 277                          SAMSUNG Guru Music 2   2520                18979
# 286  SAMSUNG Galaxy F23 5G (Copper Blush, 128 GB)  15999                15526
# 297     SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)  15999                15526
# 298  SAMSUNG Galaxy F23 5G (Forest Green, 128 GB)  15999                15526
# 359                  POCO C31 (Royal Blue, 64 GB)   9499                14025
# 173                 APPLE iPhone 12 (Red, 128 GB)  56999                12859
#
#      Overall Rating
# 333             4.4
# 357             4.5
# 325             4.5
# 25              4.4
# ...

# %%
sns.barplot(x='Total no of reviews', y=('Name'), data = Top10_most_reviewed_phones)
# Out:
# <Axes: xlabel='Total no of reviews', ylabel='Name'>

# %%
Top10_most_rated_phones = df.nlargest(10,'Total no of rating')[['Name', 'Price','Total no of rating','Overall Rating']]

# %%
Top10_most_rated_phones
# Out:
#                                         Name  Price  Total no of rating
# 333                Redmi 8 (Ruby Red, 64 GB)  10990              945272  \
# 325  Redmi Note 7 Pro (Neptune Blue, 128 GB)  17999              320949
# 357              POCO F1 (Steel Blue, 64 GB)  12299              244736
# 164           APPLE iPhone 13 (Blue, 128 GB)  57499              244100
# 166          APPLE iPhone 13 (Green, 128 GB)  57499              244100
# 169       APPLE iPhone 13 (Midnight, 128 GB)  57499              244100
# 171           APPLE iPhone 13 (Pink, 128 GB)  57499              244100
# 172      APPLE iPhone 13 (Starlight, 128 GB)  57499              244100
# 25           Honor 9N (Sapphire Blue, 32 GB)   9473              232632
# 359             POCO C31 (Royal Blue, 64 GB)   9499              226437
#
#      Overall Rating
# 333             4.4
# 325             4.5
# 357             4.5
# 164             4.7
# 166             4.7
# 169             4.7
# 171             4.7
# ...

# %%
sns.barplot(x='Total no of rating', y=('Name'), data = Top10_most_rated_phones)
# Out:
# <Axes: xlabel='Total no of rating', ylabel='Name'>

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(
    data=df, kind="line",
    x="Name", y="Total no of rating", col="Total no of reviews",
    hue="Overall Rating", style="Overall Rating",
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[96], line 2
#       1 fmri = sns.load_dataset("fmri")
# ----> 2 sns.relplot(
#       3     data=df, kind="line",
#       4     x="Name", y="Total no of rating", col="Total no of reviews",
#       5     hue="Overall Rating", style="Overall Rating",
#       6 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\relational.py:946, in relplot(data, x, y, hue, size, style, units, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     944 # Set up the FacetGrid object
#     945 facet_kws = {} if facet_kws is None else facet_kws.copy()
# --> 946 g = FacetGrid(
#     947     data=full_data.dropna(axis=1, how="all"),
#     948     **grid_kws,
# ...
